# %%
import pandas as pd


df = pd.read_csv("Dataset.csv")
df
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %% [markdown]
# 1. Write a Pandas program to display the dimensions or shape of the World alcohol consumption dataset. Also extract the column names from the dataset.

# %% [markdown]
# 2. Write a Pandas program to select first 2 rows, 2 columns and specific two columns from World alcohol consumption dataset.

# %%
first = df.iloc[:2, :2]
first
# Out:
#    Year       WHO region
# 0  1986  Western Pacific
# 1  1986         Americas

# %% [markdown]
# Write a Pandas program to select random number of rows, fraction of random rows from World alcohol consumption dataset.

# %%
random_rows = df.sample(n=5)  


f_random = df.sample(frac=0.25) 

# Display the randomly selected rows
print("Random Number of Rows:")
random_rows

print("\nFraction of Random Rows:")
f_random
# Out:
# Random Number of Rows:
#
# Fraction of Random Rows:
#     Year             WHO region                           Country  \
# 40  1987                 Europe                           Austria
# 55  1989               Americas                          Suriname
# 53  1984  Eastern Mediterranean                            Kuwait
# 17  1989                 Africa                        Seychelles
# 91  1989                 Europe                          Bulgaria
# 89  1986  Eastern Mediterranean                           Lebanon
# 88  1987  Eastern Mediterranean                           Lebanon
# 76  1985                 Africa                           Comoros
# 11  1989               Americas                         Guatemala
# 22  1984                 Europe                           Romania
# 31  1986        Western Pacific  Micronesia (Federated States of)
# 29  1986                 Europe                             Italy
# ...

# %% [markdown]
# Write a Pandas program to find and drop the missing values from World alcohol consumption dataset.

# %%
missing_values = df.isnull().sum()
print("Missing Values in the Dataset:")
print(missing_values)


df_cleaned = df.dropna()

print("\nCleaned Dataset without Missing Values:")
df_cleaned
# Out:
# Missing Values in the Dataset:
# Year              0
# WHO region        0
# Country           0
# Beverage Types    0
# Display Value     5
# dtype: int64
#
# Cleaned Dataset without Missing Values:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# ...

# %% [markdown]
# 5. Write a Pandas program to remove the duplicates from 'WHO region' column of World alcohol consumption dataset.

# %%
f_cleaned = df.drop_duplicates(subset=['WHO region'])


print("Cleaned DataFrame without Duplicates in 'WHO Region' Column:")
df_cleaned
# Out:
# Cleaned DataFrame without Duplicates in 'WHO Region' Column:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# ...

# %% [markdown]
# 6. Write a Pandas program to find out the alcohol consumption of a given year from the world alcohol consumption dataset.

# %%
year = 1985


y = df[df['Year'] == year]


y
# Out:
#     Year             WHO region  \
# 2   1985                 Africa
# 7   1985                 Africa
# 12  1985        Western Pacific
# 14  1985        Western Pacific
# 24  1985                 Africa
# 26  1985                 Europe
# 33  1985                 Africa
# 35  1985               Americas
# 44  1985                 Europe
# 50  1985                 Europe
# 63  1985  Eastern Mediterranean
# 71  1985                 Africa
# 76  1985                 Africa
# 77  1985                 Africa
# 80  1985                 Africa
# 81  1985                 Europe
# 85  1985                 Africa
# 94  1985                 Europe
# 96  1985                 Europe
# 99  1985        South-East Asia
#
#                                               Country Beverage Types  \
# 2                                        Cte d'Ivoire           Wine
# 7                                              Angola        Spirits
# ...

# %% [markdown]
# 7. Write a Pandas program to find out the alcohol consumption details in the year '1987' or '1989' from the world alcohol consumption dataset.

# %%
filtered_data = df[(df['Year'] == 1987) | (df['Year'] == 1989)]


print("Alcohol Consumption Details in the Year 1987 or 1989:")
filtered_data
# Out:
# Alcohol Consumption Details in the Year 1987 or 1989:
#     Year             WHO region                           Country  \
# 4   1987               Americas             Saint Kitts and Nevis
# 5   1987               Americas                         Guatemala
# 6   1987                 Africa                         Mauritius
# 10  1987                 Africa                          Botswana
# 11  1989               Americas                         Guatemala
# 15  1987                 Africa                     Guinea-Bissau
# 17  1989                 Africa                        Seychelles
# 21  1989               Americas                        Costa Rica
# 28  1987        Western Pacific                          Viet Nam
# 32  1989                 Africa                         Mauritius
# 36  1987  Eastern Mediterranean                             Egypt
# 38  1987  Eastern Mediterranean                             Qatar
# ...

# %% [markdown]
# 8. Write a Pandas program to find out the alcohol consumption details by the 'Americas' in the year '1985' from the world alcohol consumption dataset.

# %%
filtered_data = df[(df['Year'] == 1985) | (df['WHO region'] == 'Americas')]


print("Alcohol Consumption Details in the Americas in the Year 1985:")
filtered_data
# Out:
# Alcohol Consumption Details in the Americas in the Year 1985:
#     Year             WHO region  \
# 1   1986               Americas
# 2   1985                 Africa
# 3   1986               Americas
# 4   1987               Americas
# 5   1987               Americas
# 7   1985                 Africa
# 8   1986               Americas
# 11  1989               Americas
# 12  1985        Western Pacific
# 14  1985        Western Pacific
# 16  1984               Americas
# 21  1989               Americas
# 24  1985                 Africa
# 26  1985                 Europe
# 33  1985                 Africa
# 35  1985               Americas
# 44  1985                 Europe
# 46  1987               Americas
# 47  1986               Americas
# 48  1987               Americas
# 50  1985                 Europe
# 54  1984               Americas
# 55  1989               Americas
# 62  1987               Americas
# 63  1985  Eastern Mediterranean
# 64  1989               Americas
# ...

# %% [markdown]
# Write a Pandas program to find out the records where consumption of beverages per person average >=5 and Beverage Types is Beer from world alcohol consumption dataset.

# %%
filtered_data = df[(df['Display Value'] >= 5) & (df['Beverage Types'] == 'Beer')]

print("Records where consumption of beverages per person average >= 5 and Beverage Types is Beer:")
filtered_data
# Out:
# Records where consumption of beverages per person average >= 5 and Beverage Types is Beer:
#     Year WHO region         Country Beverage Types  Display Value
# 41  1986     Europe  Czech Republic           Beer           6.82

# %% [markdown]
# 10. Write a Pandas program to find out the records where consumption of beverages per person average >=4 and Beverage Types is Beer, Wine, Spirits from world alcohol consumption dataset.

# %%
filtered_data = df[(df['Display Value'] >= 4) & (df['Beverage Types'].isin(['Beer', 'Wine', 'Spirits']))]


print("Records where consumption of beverages per person average >= 4 and Beverage Types are Beer, Wine, or Spirits:")
filtered_data
# Out:
# Records where consumption of beverages per person average >= 4 and Beverage Types are Beer, Wine, or Spirits:
#     Year WHO region         Country Beverage Types  Display Value
# 3   1986   Americas        Colombia           Beer           4.27
# 21  1989   Americas      Costa Rica        Spirits           4.51
# 41  1986     Europe  Czech Republic           Beer           6.82
# 57  1989     Europe         Croatia           Wine           5.10
# 91  1989     Europe        Bulgaria           Beer           4.43
# 96  1985     Europe      Luxembourg           Wine           7.38

# %% [markdown]
# 11. Write a Pandas program to filter those records where WHO region contains "Ea" substring from world alcohol consumption dataset.

# %%
filtered_df = df[df['WHO region'].str.contains('Ea')]

# Display the filtered records
filtered_df
# Out:
# Empty DataFrame
# Columns: [Year, WHO region, Country, Beverage Types, Display Value]
# Index: []

# %%
# Define the list of WHO regions to match
who_regions = ['Africa', 'Eastern Mediterranean', 'Europe']

# Filter records where WHO region matches with multiple values
filtered_df = df[df['WHO region'].isin(who_regions)]

# Display the filtered records
print(filtered_df)
# Out:
#     Year WHO region            Country Beverage Types  Display Value
# 2   1985     Africa       Cte d'Ivoire           Wine           1.62
# 6   1987     Africa          Mauritius           Wine           0.13
# 7   1985     Africa             Angola        Spirits           0.39
# 9   1984     Africa            Nigeria          Other           6.10
# 10  1987     Africa           Botswana           Wine           0.20
# ..   ...        ...                ...            ...            ...
# 93  1987     Africa         Madagascar          Other           0.00
# 94  1985     Europe            Ukraine        Spirits           3.06
# 95  1984     Africa              Niger          Other           0.00
# 96  1985     Europe         Luxembourg           Wine           7.38
# 98  1984     Africa  Equatorial Guinea           Wine           0.00
#
# [69 rows x 5 columns]
